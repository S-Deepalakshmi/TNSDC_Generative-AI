# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np

# Generator model
def build_generator(latent_dim):
    model = models.Sequential()
    model.add(layers.Dense(128, input_dim=latent_dim))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dense(784, activation='tanh'))
    model.add(layers.Reshape((28, 28, 1)))
    return model

# Discriminator model
def build_discriminator(input_shape):
    model = models.Sequential()
    model.add(layers.Flatten(input_shape=input_shape))
    model.add(layers.Dense(128))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dense(1, activation='sigmoid'))
    return model

# Define the GAN
def build_gan(generator, discriminator):
    discriminator.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    discriminator.trainable = False
    gan_input = layers.Input(shape=(latent_dim,))
    gan_output = discriminator(generator(gan_input))
    gan = models.Model(gan_input, gan_output)
    gan.compile(loss='binary_crossentropy', optimizer='adam')
    return gan

# Training
def train(gan, generator, discriminator, X_train, latent_dim, num_epochs=100, batch_size=128):
    for epoch in range(num_epochs):
        # Sample random noise for generator input
        noise = np.random.normal(0, 1, size=[batch_size, latent_dim])
        # Generate fake images
        generated_images = generator.predict(noise)
        # Select a random batch of real images
        idx = np.random.randint(0, X_train.shape[0], batch_size)
        real_images = X_train[idx]
        # Concatenate real and fake images into a single array
        X = np.concatenate([real_images, generated_images])
        # Labels for generated and real data
        y_dis = np.zeros(2*batch_size)
        y_dis[:batch_size] = 0.9  # Label smoothing
        # Train discriminator
        discriminator.trainable = True
        d_loss = discriminator.train_on_batch(X, y_dis)
        # Train generator
        noise = np.random.normal(0, 1, size=[batch_size, latent_dim])
        y_gen = np.ones(batch_size)
        discriminator.trainable = False
        g_loss = gan.train_on_batch(noise, y_gen)
        # Print progress
        print(f"Epoch: {epoch+1}, Discriminator Loss: {d_loss[0]}, Generator Loss: {g_loss}")

# Example usage
latent_dim = 100
(X_train, _), (_, _) = tf.keras.datasets.mnist.load_data()
X_train = X_train / 127.5 - 1.0  # Normalize between -1 and 1
X_train = np.expand_dims(X_train, axis=-1)
generator = build_generator(latent_dim)
discriminator = build_discriminator(X_train.shape[1:])
gan = build_gan(generator, discriminator)
train(gan, generator, discriminator, X_train, latent_dim)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# 4/4 [==============================] - 0s 5ms/step
# Epoch: 1, Discriminator Loss: 1.1829414367675781, Generator Loss: 0.8066407442092896
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 2, Discriminator Loss: 0.7327414155006409, Generator Loss: 0.5101332068443298
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 3, Discriminator Loss: 1.0442578792572021, Generator Loss: 0.3581605553627014
# 4/4 [==============================] - 0s 6ms/step
# Epoch: 4, Discriminator Loss: 1.3392151594161987, Generator Loss: 0.24183624982833862
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 5, Discriminator Loss: 1.5004360675811768, Generator Loss: 0.20199790596961975
# 4/4 [==============================] - 0s 5ms/step
# Epoch: 6, Discriminator Loss: 1.5969141721725464, Generator Loss: 0.15964457392692566
# 4/4 [==============================] - 0s 5ms/step
# Epoch: 7, Discriminator Loss: 1.691319227218628, Generator Loss: 0.16261081397533417
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 8, Discriminator Loss: 1.6425466537475586, Generator Loss: 0.17135876417160034
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 9, Discriminator Loss: 1.5485787391662598, Generator Loss: 0.22462283074855804
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 10, Discriminator Loss: 1.3926407098770142, Generator Loss: 0.28447356820106506
# 4/4 [==============================] - 0s 6ms/step
# Epoch: 11, Discriminator Loss: 1.223510980606079, Generator Loss: 0.4163520634174347
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 12, Discriminator Loss: 1.0445287227630615, Generator Loss: 0.5716192722320557
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 13, Discriminator Loss: 0.8180819153785706, Generator Loss: 0.8674250245094299
# 4/4 [==============================] - 0s 5ms/step
# Epoch: 14, Discriminator Loss: 0.6429659128189087, Generator Loss: 1.2474288940429688
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 15, Discriminator Loss: 0.4819069504737854, Generator Loss: 1.6678636074066162
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 16, Discriminator Loss: 0.3886846899986267, Generator Loss: 2.0687708854675293
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 17, Discriminator Loss: 0.37342768907546997, Generator Loss: 2.428903102874756
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 18, Discriminator Loss: 0.3830580413341522, Generator Loss: 2.513852596282959
# 4/4 [==============================] - 0s 5ms/step
# Epoch: 19, Discriminator Loss: 0.39662277698516846, Generator Loss: 2.530616283416748
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 20, Discriminator Loss: 0.4045339524745941, Generator Loss: 2.394498109817505
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 21, Discriminator Loss: 0.4054762125015259, Generator Loss: 2.0484352111816406
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 22, Discriminator Loss: 0.43292152881622314, Generator Loss: 1.6998035907745361
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 23, Discriminator Loss: 0.4826822876930237, Generator Loss: 1.3924381732940674
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 24, Discriminator Loss: 0.5849474668502808, Generator Loss: 1.1514167785644531
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 25, Discriminator Loss: 0.70536869764328, Generator Loss: 0.9627361297607422
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 26, Discriminator Loss: 0.8061253428459167, Generator Loss: 0.8094488978385925
# 4/4 [==============================] - 0s 5ms/step
# Epoch: 27, Discriminator Loss: 0.922662615776062, Generator Loss: 0.7179754376411438
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 28, Discriminator Loss: 0.9984064102172852, Generator Loss: 0.7020201086997986
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 29, Discriminator Loss: 1.0163531303405762, Generator Loss: 0.73777174949646
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 30, Discriminator Loss: 0.9865714311599731, Generator Loss: 0.839625895023346
# 4/4 [==============================] - 0s 8ms/step
# Epoch: 31, Discriminator Loss: 1.0241026878356934, Generator Loss: 0.8410247564315796
# 4/4 [==============================] - 0s 6ms/step
# Epoch: 32, Discriminator Loss: 0.9635206460952759, Generator Loss: 1.0192571878433228
# 4/4 [==============================] - 0s 8ms/step
# Epoch: 33, Discriminator Loss: 0.9048265814781189, Generator Loss: 1.1645158529281616
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 34, Discriminator Loss: 0.8350392580032349, Generator Loss: 1.347076654434204
# 4/4 [==============================] - 0s 5ms/step
# Epoch: 35, Discriminator Loss: 0.7230005264282227, Generator Loss: 1.5043284893035889
# 4/4 [==============================] - 0s 6ms/step
# Epoch: 36, Discriminator Loss: 0.6299168467521667, Generator Loss: 1.7339649200439453
# 4/4 [==============================] - 0s 10ms/step
# Epoch: 37, Discriminator Loss: 0.5108180046081543, Generator Loss: 2.0093727111816406
# 4/4 [==============================] - 0s 8ms/step
# Epoch: 38, Discriminator Loss: 0.45593535900115967, Generator Loss: 2.210394859313965
# 4/4 [==============================] - 0s 5ms/step
# Epoch: 39, Discriminator Loss: 0.3875121772289276, Generator Loss: 2.451310634613037
# 4/4 [==============================] - 0s 12ms/step
# Epoch: 40, Discriminator Loss: 0.3554126024246216, Generator Loss: 2.7214813232421875
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 41, Discriminator Loss: 0.3241834044456482, Generator Loss: 2.820253372192383
# 4/4 [==============================] - 0s 7ms/step
# Epoch: 42, Discriminator Loss: 0.3062596321105957, Generator Loss: 3.047914981842041
# 4/4 [==============================] - 0s 7ms/step
# Epoch: 43, Discriminator Loss: 0.3001915216445923, Generator Loss: 3.177664279937744
# 4/4 [==============================] - 0s 12ms/step
# Epoch: 44, Discriminator Loss: 0.3077049255371094, Generator Loss: 2.9980669021606445
# 4/4 [==============================] - 0s 5ms/step
# Epoch: 45, Discriminator Loss: 0.31875574588775635, Generator Loss: 3.2517387866973877
# 4/4 [==============================] - 0s 10ms/step
# Epoch: 46, Discriminator Loss: 0.3231033980846405, Generator Loss: 3.2026610374450684
# 4/4 [==============================] - 0s 6ms/step
# Epoch: 47, Discriminator Loss: 0.33542686700820923, Generator Loss: 3.064863681793213
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 48, Discriminator Loss: 0.37465593218803406, Generator Loss: 2.8723068237304688
# 4/4 [==============================] - 0s 8ms/step
# Epoch: 49, Discriminator Loss: 0.4004673659801483, Generator Loss: 2.844881772994995
# 4/4 [==============================] - 0s 9ms/step
# Epoch: 50, Discriminator Loss: 0.4163702726364136, Generator Loss: 2.9167063236236572
# 4/4 [==============================] - 0s 9ms/step
# Epoch: 51, Discriminator Loss: 0.4093706011772156, Generator Loss: 3.097926616668701
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 52, Discriminator Loss: 0.4025788903236389, Generator Loss: 3.2334463596343994
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 53, Discriminator Loss: 0.39818084239959717, Generator Loss: 3.535877227783203
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 54, Discriminator Loss: 0.3747010827064514, Generator Loss: 3.6561503410339355
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 55, Discriminator Loss: 0.3513513505458832, Generator Loss: 3.74802303314209
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 56, Discriminator Loss: 0.33734720945358276, Generator Loss: 3.908170700073242
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 57, Discriminator Loss: 0.33444899320602417, Generator Loss: 3.7836875915527344
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 58, Discriminator Loss: 0.3455139398574829, Generator Loss: 3.686096429824829
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 59, Discriminator Loss: 0.35876011848449707, Generator Loss: 3.814000368118286
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 60, Discriminator Loss: 0.36937883496284485, Generator Loss: 3.604982852935791
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 61, Discriminator Loss: 0.3936786949634552, Generator Loss: 3.6501474380493164
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 62, Discriminator Loss: 0.4039371609687805, Generator Loss: 3.6823556423187256
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 63, Discriminator Loss: 0.4111710786819458, Generator Loss: 3.6076760292053223
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 64, Discriminator Loss: 0.4043262302875519, Generator Loss: 3.618272304534912
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 65, Discriminator Loss: 0.4164543151855469, Generator Loss: 3.6200714111328125
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 66, Discriminator Loss: 0.3923221528530121, Generator Loss: 3.7135887145996094
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 67, Discriminator Loss: 0.40546637773513794, Generator Loss: 3.808392286300659
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 68, Discriminator Loss: 0.3976399898529053, Generator Loss: 3.8521676063537598
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 69, Discriminator Loss: 0.3902937173843384, Generator Loss: 3.9810075759887695
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 70, Discriminator Loss: 0.40506240725517273, Generator Loss: 3.9439616203308105
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 71, Discriminator Loss: 0.4273778200149536, Generator Loss: 3.9440455436706543
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 72, Discriminator Loss: 0.4120944142341614, Generator Loss: 3.9029455184936523
# 4/4 [==============================] - 0s 5ms/step
# Epoch: 73, Discriminator Loss: 0.3868767023086548, Generator Loss: 3.8284993171691895
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 74, Discriminator Loss: 0.4206182360649109, Generator Loss: 3.99157452583313
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 75, Discriminator Loss: 0.4221377372741699, Generator Loss: 3.9354426860809326
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 76, Discriminator Loss: 0.39363592863082886, Generator Loss: 4.138396263122559
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 77, Discriminator Loss: 0.37950214743614197, Generator Loss: 4.04316520690918
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 78, Discriminator Loss: 0.3749677836894989, Generator Loss: 4.194258689880371
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 79, Discriminator Loss: 0.3613347113132477, Generator Loss: 4.18150520324707
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 80, Discriminator Loss: 0.333994597196579, Generator Loss: 4.229043006896973
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 81, Discriminator Loss: 0.35185322165489197, Generator Loss: 4.2048444747924805
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 82, Discriminator Loss: 0.36273813247680664, Generator Loss: 4.237486362457275
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 83, Discriminator Loss: 0.36317357420921326, Generator Loss: 4.193044185638428
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 84, Discriminator Loss: 0.3868071436882019, Generator Loss: 4.351141929626465
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 85, Discriminator Loss: 0.32775092124938965, Generator Loss: 4.403687477111816
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 86, Discriminator Loss: 0.34895169734954834, Generator Loss: 4.5667219161987305
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 87, Discriminator Loss: 0.33073335886001587, Generator Loss: 4.590236663818359
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 88, Discriminator Loss: 0.32204097509384155, Generator Loss: 4.709314823150635
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 89, Discriminator Loss: 0.29968559741973877, Generator Loss: 4.582486152648926
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 90, Discriminator Loss: 0.3278399407863617, Generator Loss: 4.457645416259766
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 91, Discriminator Loss: 0.31637847423553467, Generator Loss: 4.60554313659668
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 92, Discriminator Loss: 0.3528710603713989, Generator Loss: 4.57867956161499
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 93, Discriminator Loss: 0.34004467725753784, Generator Loss: 4.625080585479736
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 94, Discriminator Loss: 0.3272911310195923, Generator Loss: 4.7174763679504395
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 95, Discriminator Loss: 0.32119542360305786, Generator Loss: 4.812664985656738
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 96, Discriminator Loss: 0.27097415924072266, Generator Loss: 4.695201873779297
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 97, Discriminator Loss: 0.2733375132083893, Generator Loss: 4.9291253089904785
# 4/4 [==============================] - 0s 4ms/step
# Epoch: 98, Discriminator Loss: 0.29339438676834106, Generator Loss: 4.901932239532471
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 99, Discriminator Loss: 0.2784693241119385, Generator Loss: 5.27110481262207
# 4/4 [==============================] - 0s 3ms/step
# Epoch: 100, Discriminator Loss: 0.23890084028244019, Generator Loss: 5.569080352783203
